# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov5s.pt')
# Out:
# PRO TIP  Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.

# %%
def get_object_count(image_path):
    image = cv2.imread(image_path)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    results = model(image)
    detected_objects = results[0].boxes 
    num_items = len(detected_objects)
    return num_items

# %%
im = "D:\\sample.jpeg"

# %%
res = get_object_count(im)
# Out:
# 0: 480x640 4 apples, 1 orange, 195.0ms
# Speed: 3.0ms preprocess, 195.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
print("no of objects detected : ",res)
# Out:
# no of objects detected :  5
