# %%
import cv2
import tensorflow as tf
import easyocr
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model("expiry-detection.h5')

# %%
test_image = r"D://sample.jpg"

# %%
reader = easyocr.Reader(['en'])

# %%
image = cv2.imread(imagePath)
(h, w) = image.shape[:2]
image = cv2.resize(image,(224, 224))
image = img_to_array(image) / 255.0
image = np.expand_dims(image, axis=0)
preds = model.predict(image)[0]

# %%
(startX, startY, endX, endY) = preds
startX = int(startX * w)
startY = int(startY * h)
endX = int(endX * w)
endY = int(endY * h)
bb = image[startY-10:endY+10, startX-10: endX+10]

# %%
plt.imshow(bb)

# %%
crop_coordinates = startX,startY,endX,endY
cropped_image = image[crop_coordinates[0]:crop_coordinates[1], 
                       crop_coordinates[2]:crop_coordinates[3]]

# %%
results = reader.readtext(cropped_image)

# %%
print(results)
# Out:
# ['140 JUN 17']
